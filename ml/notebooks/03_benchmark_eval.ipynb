# %% [markdown]
# # WildTrace — 03. Benchmark Eval
# Run the gallery/query evaluation and compare Rank-1 (mAP@1) against the deck's cited 99.74% Amur Tiger benchmark.

# %%
import sys, subprocess

result = subprocess.run([
    sys.executable, '-m', 'ml.reid.evaluate',
    '--data', 'ml/datasets/processed',
    '--checkpoint', 'ml/reid/checkpoints/densenet121_triplet_best.pt',
], capture_output=True, text=True)

print(result.stdout)
if result.returncode != 0:
    print(result.stderr)
